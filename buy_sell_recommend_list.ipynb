# %%
# Load Data and set options
import stockdatalib as sd
import pandas as pd
from collections import defaultdict 
from datetime import datetime
from IPython.core.display import display, HTML

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', -1)
# files: screener_results.csv, constituents_csv.csv
stock_count, stock_fields, sp_df = sd.init_stocks_data('./data/','custom_stocklist.csv')
#sp_df

# %%
# Generate Buy-Sell Recommendations Table
directory = './data/'
filename = 'custom_stocklist.csv'
period = 15
# Get the Buy Sell List
tcount, bcount, scount, recomm_df = sd.GenerateBuySellList(period,directory,filename)
#link = "<a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol="+mystock.upper()+"&appCode='>"+mystock.upper()+"</a>"
#test = HTML(link)
#recomm_df['Link'] = HTML(link)
#test
#recomm_df
links = []
recomm_df2 = recomm_df.copy(deep=True)
for sym in recomm_df['Symbol']:
    link = "<a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol="+sym.upper()+"&appCode='>"+sym.upper()+"</a>"
    #link = sym
    links.append(link)
recomm_df['Symbol'] = links
HTML(recomm_df.to_html(escape=False))
# Out:
# Using stocks list in :  ./data/custom_stocklist.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Symbol</th>
#       <th>Name</th>
#       <th>Sector</th>
#       <th>Recommendation</th>
#       <th>Close</th>
#       <th>BuyAt</th>
#       <th>SellAt</th>
#       <th>Upside $</th>
#       <th>Upside %</th>
#       <th>Ave. Hold (days)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ABC&appCode='>ABC</a></td>
#       <td>AmerisourceBergen Corp</td>
#       <td>Health Care</td>
#       <td>BUY</td>
#       <td>84.03</td>
#       <td>85.50</td>
#       <td>89.42</td>
#       <td>5.39</td>
#       <td>6.41%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ADI&appCode='>ADI</a></td>
#       <td>Analog Devices, Inc.</td>
#       <td>Information Technology</td>
#       <td>BUY</td>
#       <td>105.49</td>
#       <td>103.80</td>
#       <td>108.03</td>
#       <td>2.54</td>
#       <td>2.41%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ADM&appCode='>ADM</a></td>
#       <td>Archer-Daniels-Midland Co</td>
#       <td>Consumer Staples</td>
#       <td>BUY</td>
#       <td>34.16</td>
#       <td>35.12</td>
#       <td>37.24</td>
#       <td>3.08</td>
#       <td>9.02%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ADP&appCode='>ADP</a></td>
#       <td>Automatic Data Processing</td>
#       <td>Information Technology</td>
#       <td>BUY</td>
#       <td>134.95</td>
#       <td>134.58</td>
#       <td>143.87</td>
#       <td>8.92</td>
#       <td>6.61%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=AEE&appCode='>AEE</a></td>
#       <td>Ameren Corp</td>
#       <td>Utilities</td>
#       <td>BUY</td>
#       <td>68.72</td>
#       <td>68.35</td>
#       <td>77.17</td>
#       <td>8.45</td>
#       <td>12.3%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=AEP&appCode='>AEP</a></td>
#       <td>American Electric Power</td>
#       <td>Utilities</td>
#       <td>BUY</td>
#       <td>78.10</td>
#       <td>77.73</td>
#       <td>85.48</td>
#       <td>7.38</td>
#       <td>9.45%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=AERI&appCode='>AERI</a></td>
#       <td>Aerie Pharmaceuticals Inc</td>
#       <td>Health Care</td>
#       <td>BUY</td>
#       <td>14.72</td>
#       <td>14.30</td>
#       <td>16.10</td>
#       <td>1.38</td>
#       <td>9.38%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=AES&appCode='>AES</a></td>
#       <td>AES Corp</td>
#       <td>Utilities</td>
#       <td>BUY</td>
#       <td>11.82</td>
#       <td>12.94</td>
#       <td>13.99</td>
#       <td>2.17</td>
#       <td>18.36%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=AIV&appCode='>AIV</a></td>
#       <td>Apartment Investment & Management</td>
#       <td>Real Estate</td>
#       <td>BUY</td>
#       <td>33.55</td>
#       <td>36.03</td>
#       <td>39.02</td>
#       <td>5.47</td>
#       <td>16.3%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=AIZ&appCode='>AIZ</a></td>
#       <td>Assurant Inc.</td>
#       <td>Financials</td>
#       <td>BUY</td>
#       <td>89.05</td>
#       <td>87.76</td>
#       <td>112.39</td>
#       <td>23.34</td>
#       <td>26.21%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ALL&appCode='>ALL</a></td>
#       <td>Allstate Corp</td>
#       <td>Financials</td>
#       <td>BUY</td>
#       <td>93.92</td>
#       <td>92.08</td>
#       <td>102.44</td>
#       <td>8.52</td>
#       <td>9.07%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ALNY&appCode='>ALNY</a></td>
#       <td>Alnylam Pharmaceuticals Inc</td>
#       <td>Health Care</td>
#       <td>BUY</td>
#       <td>136.20</td>
#       <td>136.13</td>
#       <td>145.63</td>
#       <td>9.43</td>
#       <td>6.92%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=AMN&appCode='>AMN</a></td>
#       <td>AMN Healthcare Services Inc.</td>
#       <td>Health Care</td>
#       <td>BUY</td>
#       <td>40.33</td>
#       <td>42.58</td>
#       <td>55.13</td>
#       <td>14.80</td>
#       <td>36.7%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=AMT&appCode='>AMT</a></td>
#       <td>American Tower Corp A</td>
#       <td>Real Estate</td>
#       <td>BUY</td>
#       <td>229.62</td>
#       <td>234.20</td>
#       <td>255.10</td>
#       <td>25.48</td>
#       <td>11.1%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ANSS&appCode='>ANSS</a></td>
#       <td>ANSYS</td>
#       <td>Information Technology</td>
#       <td>BUY</td>
#       <td>252.15</td>
#       <td>252.11</td>
#       <td>258.95</td>
#       <td>6.80</td>
#       <td>2.7%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=APH&appCode='>APH</a></td>
#       <td>Amphenol Corp</td>
#       <td>Information Technology</td>
#       <td>BUY</td>
#       <td>83.28</td>
#       <td>81.82</td>
#       <td>87.53</td>
#       <td>4.25</td>
#       <td>5.1%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=APHA&appCode='>APHA</a></td>
#       <td>Aphria Inc</td>
#       <td>Health Care</td>
#       <td>BUY</td>
#       <td>3.02</td>
#       <td>2.96</td>
#       <td>3.19</td>
#       <td>0.17</td>
#       <td>5.63%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=APLS&appCode='>APLS</a></td>
#       <td>Apellis Pharmaceuticals Inc</td>
#       <td>Health Care</td>
#       <td>BUY</td>
#       <td>30.34</td>
#       <td>29.83</td>
#       <td>38.49</td>
#       <td>8.15</td>
#       <td>26.86%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ARE&appCode='>ARE</a></td>
#       <td>Alexandria Real Estate Equities Inc</td>
#       <td>Real Estate</td>
#       <td>BUY</td>
#       <td>140.53</td>
#       <td>143.46</td>
#       <td>155.36</td>
#       <td>14.83</td>
#       <td>10.55%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><a target='_blank' href='https://snapshot.fidelity.com/fidresearch/snapshot/landing.jhtml#/research?symbol=ARQT&appCode='>ARQT</a></td>
#       <td>Arcutis Biotherapeutics Inc</td>
#       <td>Health Care</td>
#       <td>BUY</td>

# %%
# create a list of stock symbols
dateTimeObj = datetime.now()
timestampStr = dateTimeObj.strftime("%Y-%b-%d-%H-%M-%S")
logdir = "./logs/"    
    
if not recomm_df2.empty:
    recomm_filename = logdir + "stock_recommendations_" + timestampStr + ".csv"
    sd.SaveBuySellList2File(recomm_filename,recomm_df2)
    recomm_filename = logdir + "stock_recommendations_latest.csv"
    sd.SaveBuySellList2File(recomm_filename,recomm_df2)
# Out:
# Table writen to file "./logs/stock_recommendations_2020-May-15-07-30-47.csv"
# Table writen to file "./logs/stock_recommendations_latest.csv"
